# %% [markdown]
# <a href="https://colab.research.google.com/github/sairam1099-hyd/langchain_table_.ipynb/blob/main/langchain_table_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 2.9 MB/s eta 0:00:00
# ...

# %%
from langchain.chat_models import init_chat_model
from google.colab import userdata

# %%
api_key= userdata.get("GEMINI_API_KEY")

# %%
model = init_chat_model(
    'google_genai:gemini-2.5-flash',
    api_key=api_key
)

# %%
response = model.invoke('explain central limit theorem')
print(response)
# Out:
# content='The **Central Limit Theorem (CLT)** is one of the most fundamental and powerful theorems in statistics. It\'s often considered the "magic" behind why the normal distribution is so important.\n\nIn a nutshell, the Central Limit Theorem states:\n\n**If you take many random samples from *any* population (regardless of its shape), and calculate the mean of *each* sample, the distribution of *these sample means* will tend to be a normal distribution.**\n\nThis holds true **even if the original population distribution was not normal** (e.g., skewed, uniform, exponential, etc.), as long as your sample size is "large enough."\n\n---\n\nLet\'s break that down with an analogy:\n\n**Imagine a population:**\nLet\'s say you\'re interested in the **average income** of all adults in a very large city. The distribution of individual incomes in a city is probably *not* normal; it\'s likely skewed to the right (a few very rich people pull the average up, while most people earn less).\n\n**The
# ...

# %%
from langchain.chat_models import init_chat_model
from langchain.messages import HumanMessage, SystemMessage

from google.colab import userdata
api_key=userdata.get('GEMINI_API_KEY')

system_msg = SystemMessage("You are a helpful assistant.")
human_msg = HumanMessage("What are cars ?")
messages = [system_msg, human_msg]

model = init_chat_model(
  "google_genai:gemini-2.5-flash",
  api_key=api_key,
)

response = model.invoke(messages)
print(response.content)
# Out:
# A car, short for **automobile**, is a **wheeled motor vehicle** used for **transportation**.
#
# Here's a breakdown of what that means:
#
# 1.  **Wheeled:** Cars have wheels (typically four) that allow them to roll along a surface.
# 2.  **Motor Vehicle:** This means they are self-propelled, typically by an **engine** (internal combustion or electric motor) that converts fuel (gasoline, diesel, electricity) into motion.
# 3.  **Transportation:** Their primary purpose is to move people and/or goods from one place to another.
#
# **Key Characteristics and Components:**
#
# *   **Engine/Motor:** The power source that drives the wheels.
# *   **Chassis/Frame:** The structural base that supports all other components.
# *   **Body:** The outer shell, providing protection, aerodynamics, and aesthetics.
# *   **Wheels and Tires:** For movement and grip on the road.
# *   **Steering System:** Allows the driver to control the direction of the car.
# ...
